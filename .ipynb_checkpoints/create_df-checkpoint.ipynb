# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import preprocessing as pp
# %matplotlib inline

# %%
def two_digits_n(n):
    if n<10:
        return '0' + str(n)
    else:
        return str(n)

# %%
xcel = pd.read_excel(
    '/Volumes/Daive/spring_2016/excel/spring_2016.xlsx', 
    'Cleaned', 
    index_col='coil'
)

# %%
xcel['t0'] = np.nan
xcel['t1'] = np.nan
xcel
# Out:
#       coil_chrono  coil_number datum_post  real_date                time  \
# coil
# 0              53     61329256 2016-06-18 2016-06-18 2016-09-12 01:13:30
# 1              43     60674005 2016-05-28 2016-05-28 2016-09-12 03:29:05
# 2              50     61157303 2016-06-13 2016-06-13 2016-09-12 00:28:58
# 3              39     60011835 2016-05-05 2016-05-05 2016-09-12 11:58:17
# 4              42     60179906 2016-05-11 2016-05-11 2016-09-12 12:56:20
# 5               0     58360839 2016-03-12 2016-03-12 2016-04-11 11:26:26
# 6              28     59610261 2016-04-23 2016-04-23 2016-05-09 00:11:13
# 7              59     61441985 2016-06-22 2016-06-22 2016-09-12 00:14:09
# 8              24     59518934 2016-04-18 2016-04-18 2016-05-09 04:01:59
# 9              29     59630090 2016-04-23 2016-04-23 2016-05-09 09:35:20
# 10             17     59109583 2016-04-04 2016-04-04 2016-05-09 03:23:34
# 11             40     60044844 2016-05-06 2016-05-06 2016-09-12 16:32:34
# ...

# %%
nom = '/Volumes/Daive/spring_2016/txt/coil_'
col_names = ['time', 'signal', 'accelerometer', 'speed', 'coiler', 'decoiler']
for i in range(62):
    num = two_digits_n(i)
    fichier = nom + num + '.txt'
    df = pd.read_csv(
        fichier,
        sep='\t',
        names=col_names,
        skiprows=11,
        header=0,
        index_col=None
        )
    a, b = pp.when_sticking(df.decoiler.values, df.time.values, xcel.startS[i], xcel.endS[i])
    xcel.t0.set_value(i, a)
    xcel.t1.set_value(i, b)

# %%
from pandas import ExcelWriter
writer = ExcelWriter('output.xlsx')
xcel.to_excel(writer,'Sheet1')
writer.save()

# %%
num = two_digits_n(4)
fichier = nom + num + '.txt'
df = pd.read_csv(
    fichier,
    sep='\t',
    names=col_names,
    skiprows=11,
    header=0,
    index_col=None
    )

# %%
df.coiler[df.time==375]
# Out:
# 3750000    17.453415
# Name: coiler, dtype: float64

# %%
plt.plot(df.coiler, df.time)

# %%
import scipy
f = scipy.interpolate.interp1d(df.decoiler.values, df.time.values)

# %%
f(100)
# Out:
# array(105.5488145256278)

# %%
df.decoiler[df.time==106]
# Out:
# 1060000    101.56132
# Name: decoiler, dtype: float64

# %%
xcel
# Out:
#       coil_chrono  coil_number datum_post  real_date                time  \
# coil
# 0              53     61329256 2016-06-18 2016-06-18 2016-09-12 01:13:30
# 1              43     60674005 2016-05-28 2016-05-28 2016-09-12 03:29:05
# 2              50     61157303 2016-06-13 2016-06-13 2016-09-12 00:28:58
# 3              39     60011835 2016-05-05 2016-05-05 2016-09-12 11:58:17
# 4              42     60179906 2016-05-11 2016-05-11 2016-09-12 12:56:20
# 5               0     58360839 2016-03-12 2016-03-12 2016-04-11 11:26:26
# 6              28     59610261 2016-04-23 2016-04-23 2016-05-09 00:11:13
# 7              59     61441985 2016-06-22 2016-06-22 2016-09-12 00:14:09
# 8              24     59518934 2016-04-18 2016-04-18 2016-05-09 04:01:59
# 9              29     59630090 2016-04-23 2016-04-23 2016-05-09 09:35:20
# 10             17     59109583 2016-04-04 2016-04-04 2016-05-09 03:23:34
# 11             40     60044844 2016-05-06 2016-05-06 2016-09-12 16:32:34
# ...

# %%
for i in xcel.index:
    if np.isnan(xcel.startS[i]):
        xcel.t0.set_value(i, np.nan)
        xcel.t1.set_value(i, np.nan)
